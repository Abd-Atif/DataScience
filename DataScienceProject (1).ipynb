# %%
#                      PROJECT  -->    Introduction to Data Science  



#      m abdurrehman atif     L1S18BSCS0092
#     amar hussain           L1F17BSCS0094

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sea
# %matplotlib inline

# %%
fullodi_df = pd.read_csv('ContinousDataset.csv')
type(fullodi_df)
# Out:
# pandas.core.frame.DataFrame

# %%
fullodi_df
# Out:
#       Unnamed: 0   Scorecard       Team 1       Team 2           Margin  \
# 0              0     ODI # 1    Australia      England  Winner2ndInning
# 1              1     ODI # 2      England    Australia  Winner2ndInning
# 2              2     ODI # 3      England    Australia  Winner2ndInning
# 3              3     ODI # 4      England    Australia  Winner2ndInning
# 4              4     ODI # 5  New Zealand     Pakistan  Winner1stInning
# ...          ...         ...          ...          ...              ...
# 7489        3747  ODI # 3931  New Zealand        India  Winner2ndInning
# 7490        3748  ODI # 3932  New Zealand        India  Winner1stInning
# 7491        3749  ODI # 3933      Namibia    Hong Kong  Winner2ndInning
# 7492        3750  ODI # 3934       U.S.A.      Bermuda  Winner2ndInning
# 7493        3749  ODI # 3935      Namibia  East Africa  Winner1stInning
#
#             Ground    Match Date       Winner Host_Country Venue_Team1  \
# ...

# %%
shapeRowsCol = fullodi_df.shape
print("rows , columns")
print(shapeRowsCol)
# Out:
# rows , columns
# (7494, 13)

# %%
all_columns = fullodi_df.iloc[:0,0:]
all_columns
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Scorecard, Team 1, Team 2, Margin, Ground, Match Date, Winner, Host_Country, Venue_Team1, Venue_Team2, Innings_Team1, Innings_Team2]
# Index: []

# %%
odi_df = fullodi_df.iloc[:,1:10]
odi_df
# Out:
#        Scorecard       Team 1       Team 2           Margin        Ground  \
# 0        ODI # 1    Australia      England  Winner2ndInning     Melbourne
# 1        ODI # 2      England    Australia  Winner2ndInning    Manchester
# 2        ODI # 3      England    Australia  Winner2ndInning        Lord's
# 3        ODI # 4      England    Australia  Winner2ndInning    Birmingham
# 4        ODI # 5  New Zealand     Pakistan  Winner1stInning  Christchurch
# ...          ...          ...          ...              ...           ...
# 7489  ODI # 3931  New Zealand        India  Winner2ndInning          Pune
# 7490  ODI # 3932  New Zealand        India  Winner1stInning        Kanpur
# 7491  ODI # 3933      Namibia    Hong Kong  Winner2ndInning        Mumbai
# 7492  ODI # 3934       U.S.A.      Bermuda  Winner2ndInning        Mumbai
# 7493  ODI # 3935      Namibia  East Africa  Winner1stInning        Mumbai
#
#         Match Date       Winner Host_Country Venue_Team1
# ...

# %%
number_of_teams = odi_df['Team 1'].unique()

# %%
number_of_teams
# Out:
# array(['Australia', 'England', 'New Zealand', 'East Africa', 'Sri Lanka',
#        'Pakistan', 'India', 'West Indies', 'Canada', 'Bangladesh',
#        'South Africa', 'Zimbabwe', 'U.A.E.', 'Netherlands', 'Kenya',
#        'Scotland', 'Namibia', 'Hong Kong', 'Bermuda', 'Ireland',
#        'Afghanistan', 'P.N.G.', 'U.S.A.'], dtype=object)

# %%
print("Total number of teams, that present in this ODI data is ")
print(len(number_of_teams))
# Out:
# Total number of teams, that present in this ODI data is
# 23

# %%
grounds = odi_df['Ground'].unique()
type(grounds)
# Out:
# numpy.ndarray

# %%
grounds.sort()

# %%
grounds 
#alphabetical
# Out:
# array(['Aberdeen', 'Abu Dhabi', 'Adelaide', 'Ahmedabad', 'Albion',
#        'Albury', 'Amritsar', 'Amstelveen', 'Auckland', 'Ayr', 'Ballarat',
#        'Basseterre', 'Belfast', 'Bengaluru', 'Benoni', 'Berri',
#        'Birmingham', 'Bloemfontein', 'Bogra', 'Bridgetown', 'Brisbane',
#        'Bristol', 'Bulawayo', 'Cairns', 'Canberra', 'Canterbury',
#        'Cape Town', 'Cardiff', 'Castries', 'Centurion', 'Chandigarh',
#        'Chelmsford', 'Chennai', 'Chester', 'Chittagong', 'Christchurch',
#        'Colombo', 'Cuttack', 'Dambulla', 'Darwin', 'Delhi', 'Derby',
#        'Devonport', 'Dhaka', 'Dharamsala', 'Dubai', 'Dublin', 'Dunedin',
#        'Durban', 'East London', 'Edinburgh', 'Faisalabad', 'Faridabad',
#        'Fatullah', 'Galle', 'Georgetown', 'Glasgow', 'Greater Noida',
#        'Gros Islet', 'Gujranwala', 'Guwahati', 'Gwalior', 'Hambantota',
#        'Hamilton', 'Harare', 'Hobart', 'Hove', 'Hyderabad', 'ICCA Dubai',
# ...

# %%
print("Total numbers of ground present in this data is ",(len(grounds)))
# Out:
# Total numbers of ground present in this data is  161

# %%
years_list = odi_df['Match Date']
years = [x[-4:]for x in years_list] 
type(years)
# Out:
# list

# %%
years
# Out:
# ['1971',
#  '1972',
#  '1972',
#  '1972',
#  '1973',
#  '1973',
#  '1973',
#  '1973',
#  '1974',
#  '1974',
#  '1974',
#  '1974',
#  '1974',
#  '1974',
#  '1975',
#  '1975',
#  '1975',
#  '1975',
#  '1975',
#  '1975',
#  '1975',
#  '1975',
#  '1975',
#  '1975',
#  '1975',
#  '1975',
#  '1975',
#  '1975',
#  '1975',
#  '1975',
#  '1975',
#  '1976',
#  '1976',
#  '1976',
#  '1976',
#  '1976',
#  '1976',
#  '1977',
#  '1977',
#  '1977',
#  '1977',
#  '1977',
#  '1977',
#  '1978',
#  '1978',
#  '1978',
#  '1978',
#  '1978',
#  '1978',
#  '1978',
#  '1978',
#  '1978',
#  '1979',
#  '1979',
#  '1979',
#  '1979',
#  '1979',
#  '1979',
#  '1979',
#  '1979',
#  '1979',
#  '1979',
#  '1979',
#  '1979',
#  '1979',
#  '1979',
#  '1979',
#  '1979',
#  '1979',
#  '1979',
#  '1979',
#  '1979',
#  '1979',
#  '1979',
#  '1979',
#  '1979',
#  '1979',
#  '1980',
#  '1980',
#  '1980',
#  '1980',
#  '1980',
#  '1980',
#  '1980',
#  '1980',
#  '1980',
#  '1980',
#  '1980',
#  '1980',
#  '1980',
# ...

# %%
years_int = []

for x in years:
    years_int.append(int(x))       
print(type(years_int))
# Out:
# <class 'list'>

# %%
years_int_s = pd.Series(years_int)
print(type(years_int_s))
# Out:
# <class 'pandas.core.series.Series'>

# %%
print("\nNumber of matches played in each years from 1971 to 2017")
print(years_int_s.value_counts())
# Out:
# Number of matches played in each years from 1971 to 2017
# 2007    360
# 2006    308
# 1999    290
# 2009    286
# 2015    282
# 2003    282
# 2011    280
# 2010    280
# 2002    274
# 2000    254
# 2013    248
# 1996    244
# 2004    244
# 2001    238
# 2014    236
# 2008    232
# 2017    224
# 1997    214
# 1998    212
# 1994    188
# 2005    188
# 2016    182
# 1992    168
# 2012    168
# 1993    154
# 1987    146
# 1983    128
# 1985    124
# 1988    120
# 1990    118
# 1986    118
# 1995    118
# 1989    106
# 1984     92
# 1991     74
# 1982     64
# 1981     54
# 1979     50
# 1980     42
# 1975     34
# 1978     18
# 1974     12
# 1977     12
# 1976     12
# 1973      8
# 1972      6
# 1971      2
# dtype: int64

# %%
Grounds = odi_df['Ground']

# %%
matches_played_in_each_ground = Grounds.value_counts()
matches_played_in_each_ground
# Out:
# Sharjah         452
# Colombo         358
# Dhaka           308
# Melbourne       300
# Sydney          294
#                ...
# Devonport         2
# Sargodha          2
# New Plymouth      2
# Whangarei         2
# Launceston        2
# Name: Ground, Length: 161, dtype: int64

# %%
matches_played_in_pakistani_grounds = matches_played_in_each_ground[['Gujranwala','Sahiwal','Lahore','Peshawar',
                                                                     'Rawalpindi', 'Karachi','Quetta','Sargodha',
  
                                                                     'Sheikhupura', 'Sialkot','Multan','Faisalabad','Hyderabad']]
print("Number of matches played in Pakistani grounds.\n")
print(matches_played_in_pakistani_grounds)
# Out:
# Number of matches played in Pakistani grounds.
#
# Gujranwala      22
# Sahiwal          2
# Lahore         116
# Peshawar        30
# Rawalpindi      46
# Karachi         88
# Quetta           6
# Sargodha         2
# Sheikhupura      4
# Sialkot         16
# Multan          26
# Faisalabad      32
# Hyderabad       48
# Name: Ground, dtype: int64

# %%
total_no_of_matches_played_in_Pakistan = matches_played_in_pakistani_grounds.sum()
print("Total matches played in Pakistani stadium from 1971  to 2017 is",(total_no_of_matches_played_in_Pakistan))
# Out:
# Total matches played in Pakistani stadium from 1971  to 2017 is 438

# %%
Pakistan_in_team1 =  odi_df[odi_df['Team 1'] == 'Pakistan']
Pakistan_in_team2 =  odi_df[odi_df['Team 2'] == 'Pakistan']

# %%
Pakistan_in_team1
# Out:
#        Scorecard    Team 1       Team 2           Margin      Ground  \
# 22      ODI # 26  Pakistan  West Indies  Winner2ndInning  Birmingham
# 26      ODI # 30  Pakistan    Sri Lanka  Winner1stInning  Nottingham
# 36      ODI # 40  Pakistan  New Zealand  Winner1stInning     Sialkot
# 41      ODI # 45  Pakistan      England  Winner2ndInning     Sahiwal
# 42      ODI # 46  Pakistan      England  Winner2ndInning     Sialkot
# ...          ...       ...          ...              ...         ...
# 7426  ODI # 3862  Pakistan  West Indies  Winner1stInning  Providence
# 7427  ODI # 3863  Pakistan  West Indies  Winner2ndInning  Providence
# 7440  ODI # 3878  Pakistan        India  Winner1stInning  Birmingham
# 7450  ODI # 3889  Pakistan      England  Winner2ndInning     Cardiff
# 7454  ODI # 3894  Pakistan        India  Winner1stInning    The Oval
#
#         Match Date       Winner Host_Country Venue_Team1
# 22    Jun 11, 1975  West Indies      England     Neutral
# ...

# %%
Pakistan_in_team2
# Out:
#        Scorecard       Team 1    Team 2           Margin        Ground  \
# 4        ODI # 5  New Zealand  Pakistan  Winner1stInning  Christchurch
# 12      ODI # 14      England  Pakistan  Winner2ndInning    Nottingham
# 13      ODI # 15      England  Pakistan  Winner2ndInning    Birmingham
# 17      ODI # 21    Australia  Pakistan  Winner1stInning         Leeds
# 37      ODI # 41  West Indies  Pakistan  Winner2ndInning        Albion
# ...          ...          ...       ...              ...           ...
# 7480  ODI # 3922    Sri Lanka  Pakistan  Winner1stInning         Dubai
# 7482  ODI # 3924    Sri Lanka  Pakistan  Winner1stInning     Abu Dhabi
# 7484  ODI # 3926    Sri Lanka  Pakistan  Winner2ndInning     Abu Dhabi
# 7485  ODI # 3927    Sri Lanka  Pakistan  Winner2ndInning       Sharjah
# 7488  ODI # 3930    Sri Lanka  Pakistan  Winner2ndInning       Sharjah
#
#         Match Date       Winner Host_Country Venue_Team1
# 4     Feb 11, 1973  New Zealand  New Zealand        Home
# ...

# %%
#    .concat() is a function of the panda's 
#    data frame that joins two or more data
#    frames to each other on axis basis ( row-wise and column-wise).
#    Axis = 1 denotes the columns wise and axis = 0 denotes the rows wise of the data frame.

# %%
total_matches_played_by_Pakistan = pd.concat([Pakistan_in_team1,Pakistan_in_team2 ],axis=0,ignore_index=True)

# %%
total_matches_played_by_Pakistan
# Out:
#        Scorecard     Team 1       Team 2           Margin      Ground  \
# 0       ODI # 26   Pakistan  West Indies  Winner2ndInning  Birmingham
# 1       ODI # 30   Pakistan    Sri Lanka  Winner1stInning  Nottingham
# 2       ODI # 40   Pakistan  New Zealand  Winner1stInning     Sialkot
# 3       ODI # 45   Pakistan      England  Winner2ndInning     Sahiwal
# 4       ODI # 46   Pakistan      England  Winner2ndInning     Sialkot
# ...          ...        ...          ...              ...         ...
# 1703  ODI # 3922  Sri Lanka     Pakistan  Winner1stInning       Dubai
# 1704  ODI # 3924  Sri Lanka     Pakistan  Winner1stInning   Abu Dhabi
# 1705  ODI # 3926  Sri Lanka     Pakistan  Winner2ndInning   Abu Dhabi
# 1706  ODI # 3927  Sri Lanka     Pakistan  Winner2ndInning     Sharjah
# 1707  ODI # 3930  Sri Lanka     Pakistan  Winner2ndInning     Sharjah
#
#         Match Date       Winner Host_Country Venue_Team1
# 0     Jun 11, 1975  West Indies      England     Neutral
# ...

# %%
total_matches_played_by_Pakistan.value_counts()
# Out:
# Scorecard   Team 1        Team 2        Margin           Ground      Match Date    Winner        Host_Country  Venue_Team1
# ODI # 1003  Pakistan      Sri Lanka     Winner2ndInning  Gujranwala  Sep 29, 1995  Pakistan      Pakistan      Home           1
#             Sri Lanka     Pakistan      Winner2ndInning  Gujranwala  Sep 29, 1995  Pakistan      Pakistan      Away           1
# ODI # 3530  Australia     Pakistan      Winner1stInning  Sharjah     Oct 7, 2014   Australia     U.A.E.        Neutral        1
# ODI # 3519  Sri Lanka     Pakistan      Winner2ndInning  Dambulla    Aug 30, 2014  Sri Lanka     Sri Lanka     Home           1
#             Pakistan      Sri Lanka     Winner2ndInning  Dambulla    Aug 30, 2014  Sri Lanka     Sri Lanka     Away           1
#                                                                                                                              ..
# ...

# %%
print('Total matches played by Pakistan from 1971 to 2017 is ',(total_matches_played_by_Pakistan.shape[0]))
# Out:
# Total matches played by Pakistan from 1971 to 2017 is  1708

# %%
matches_played_in_indian_grounds = matches_played_in_each_ground[['Ahmedabad','Amritsar','Bengaluru','Chandigarh','Chennai','Delhi','Dharamsala',
                                                               'Faridabad','Greater Noida','Guwahati','Gwalior','Indore', 'Jaipur', 'Jalandhar',
                                                                'Jamshedpur', 'Jodhpur','Kanpur','Kochi','Kolkata','Lucknow','Mohali', 'Mombasa',
                                                                'Mumbai', 'Nagpur','New Delhi','Patna','Pune', 'Rajkot', 'Ranchi',
                                                               'Srinagar','Thiruvananthapuram','Vadodara', 'Vijayawada', 'Visakhapatnam']]
print("Number of matches played in Indian grounds.\n")
print(matches_played_in_indian_grounds)
# Out:
# Number of matches played in Indian grounds.
#
# Ahmedabad             48
# Amritsar               4
# Bengaluru             42
# Chandigarh            10
# Chennai               36
# Delhi                 46
# Dharamsala             6
# Faridabad             16
# Greater Noida         10
# Guwahati              28
# Gwalior               24
# Indore                24
# Jaipur                38
# Jalandhar              6
# Jamshedpur            18
# Jodhpur                4
# Kanpur                30
# Kochi                 18
# Kolkata               56
# Lucknow                2
# Mohali                46
# Mombasa               24
# Mumbai                64
# Nagpur                44
# New Delhi              4
# Patna                  4
# Pune                  28
# Rajkot                28
# Ranchi                 6
# Srinagar               4
# Thiruvananthapuram     2
# Vadodara              26
# Vijayawada             2
# Visakhapatnam         22
# Name: Ground, dtype: int64

# %%
total_no_of_matches_played_in_India = matches_played_in_indian_grounds.sum()
print("Total matches played in Indian stadium from 1971  to 2017 is {}.".format(total_no_of_matches_played_in_India))
# Out:
# Total matches played in Indian stadium from 1971  to 2017 is 770.

# %%
India_in_team1 =  odi_df[odi_df['Team 1'] == 'India']
India_in_team2 =  odi_df[odi_df['Team 2'] == 'India']

# %%
India_in_team1
# Out:
#        Scorecard Team 1       Team 2           Margin      Ground  \
# 24      ODI # 28  India  New Zealand  Winner2ndInning  Manchester
# 55      ODI # 61  India  West Indies  Winner2ndInning  Birmingham
# 59      ODI # 65  India  New Zealand  Winner2ndInning       Leeds
# 62      ODI # 68  India    Sri Lanka  Winner1stInning  Manchester
# 93      ODI # 99  India  New Zealand  Winner1stInning       Perth
# ...          ...    ...          ...              ...         ...
# 7464  ODI # 3905  India    Sri Lanka  Winner2ndInning    Dambulla
# 7465  ODI # 3906  India    Sri Lanka  Winner2ndInning   Pallekele
# 7466  ODI # 3907  India    Sri Lanka  Winner2ndInning   Pallekele
# 7467  ODI # 3908  India    Sri Lanka  Winner1stInning     Colombo
# 7468  ODI # 3909  India    Sri Lanka  Winner2ndInning     Colombo
#
#            Match Date       Winner Host_Country Venue_Team1
# 24       Jun 14, 1975  New Zealand      England     Neutral
# ...

# %%
India_in_team2
# Out:
#        Scorecard       Team 1 Team 2           Margin        Ground  \
# 10      ODI # 12      England  India  Winner2ndInning         Leeds
# 11      ODI # 13      England  India  Winner2ndInning      The Oval
# 15      ODI # 19      England  India  Winner1stInning        Lord's
# 20      ODI # 24  East Africa  India  Winner2ndInning         Leeds
# 31      ODI # 35  New Zealand  India  Winner2ndInning  Christchurch
# ...          ...          ...    ...              ...           ...
# 7475  ODI # 3917    Australia  India  Winner1stInning     Bengaluru
# 7477  ODI # 3919    Australia  India  Winner2ndInning        Nagpur
# 7486  ODI # 3928  New Zealand  India  Winner2ndInning        Mumbai
# 7489  ODI # 3931  New Zealand  India  Winner2ndInning          Pune
# 7490  ODI # 3932  New Zealand  India  Winner1stInning        Kanpur
#
#            Match Date       Winner Host_Country Venue_Team1
# 10       Jul 13, 1974      England      England        Home
# ...

# %%
total_matches_played_by_India = pd.concat([India_in_team1,India_in_team2 ],axis=0,ignore_index=True)
total_matches_played_by_India
# Out:
#        Scorecard       Team 1       Team 2           Margin      Ground  \
# 0       ODI # 28        India  New Zealand  Winner2ndInning  Manchester
# 1       ODI # 61        India  West Indies  Winner2ndInning  Birmingham
# 2       ODI # 65        India  New Zealand  Winner2ndInning       Leeds
# 3       ODI # 68        India    Sri Lanka  Winner1stInning  Manchester
# 4       ODI # 99        India  New Zealand  Winner1stInning       Perth
# ...          ...          ...          ...              ...         ...
# 1755  ODI # 3917    Australia        India  Winner1stInning   Bengaluru
# 1756  ODI # 3919    Australia        India  Winner2ndInning      Nagpur
# 1757  ODI # 3928  New Zealand        India  Winner2ndInning      Mumbai
# 1758  ODI # 3931  New Zealand        India  Winner2ndInning        Pune
# 1759  ODI # 3932  New Zealand        India  Winner1stInning      Kanpur
#
#            Match Date       Winner Host_Country Venue_Team1
# ...

# %%
total_matches_played_by_India.value_counts()
# Out:
# Scorecard   Team 1       Team 2       Margin           Ground         Match Date    Winner     Host_Country  Venue_Team1
# ODI # 100   Australia    India        Winner2ndInning  Sydney         Dec 18, 1980  Australia  Australia     Home           1
# ODI # 3388  India        Sri Lanka    Winner2ndInning  Port of Spain  Jul 11, 2013  India      West Indies   Neutral        1
# ODI # 3387  India        Sri Lanka    Winner1stInning  Port of Spain  Jul 9, 2013   India      West Indies   Neutral        1
# ODI # 3383  West Indies  India        Winner1stInning  Port of Spain  Jul 5, 2013   India      West Indies   Home           1
#             India        West Indies  Winner1stInning  Port of Spain  Jul 5, 2013   India      West Indies   Away           1
#                                                                                                                            ..
# ...

# %%
print('Total matches played by India from 1971 to 2017 is ',(total_matches_played_by_India.shape[0]))
# Out:
# Total matches played by India from 1971 to 2017 is  1760

# %%
sea.set_style('darkgrid')
matplotlib.rcParams['font.size'] = 13
matplotlib.rcParams['figure.figsize'] = (13, 6)
#matplotlib.rcParams['figure.facecolor'] = '#00000000'

# %%
# for a graph, that shows the maximum numbers of matches played in the top 15 years between 1971 and 2017
years_int_s
# Out:
# 0       1971
# 1       1972
# 2       1972
# 3       1972
# 4       1973
#         ...
# 7489    2017
# 7490    2017
# 7491    2017
# 7492    2017
# 7493    2017
# Length: 7494, dtype: int64

# %%
years_int_s.value_counts()
# Out:
# 2007    360
# 2006    308
# 1999    290
# 2009    286
# 2015    282
# 2003    282
# 2011    280
# 2010    280
# 2002    274
# 2000    254
# 2013    248
# 1996    244
# 2004    244
# 2001    238
# 2014    236
# 2008    232
# 2017    224
# 1997    214
# 1998    212
# 1994    188
# 2005    188
# 2016    182
# 1992    168
# 2012    168
# 1993    154
# 1987    146
# 1983    128
# 1985    124
# 1988    120
# 1990    118
# 1986    118
# 1995    118
# 1989    106
# 1984     92
# 1991     74
# 1982     64
# 1981     54
# 1979     50
# 1980     42
# 1975     34
# 1978     18
# 1974     12
# 1977     12
# 1976     12
# 1973      8
# 1972      6
# 1971      2
# dtype: int64

# %%
years_int_s.value_counts().index
# Out:
# Int64Index([2007, 2006, 1999, 2009, 2015, 2003, 2011, 2010, 2002, 2000, 2013,
#             1996, 2004, 2001, 2014, 2008, 2017, 1997, 1998, 1994, 2005, 2016,
#             1992, 2012, 1993, 1987, 1983, 1985, 1988, 1990, 1986, 1995, 1989,
#             1984, 1991, 1982, 1981, 1979, 1980, 1975, 1978, 1974, 1977, 1976,
#             1973, 1972, 1971],
#            dtype='int64')

# %%
list_of_years = list(years_int_s.value_counts().index) 
top15_years_by_matches_held =  list_of_years[:15]
print(years_int_s.value_counts().head(15))
# Out:
# 2007    360
# 2006    308
# 1999    290
# 2009    286
# 2015    282
# 2003    282
# 2011    280
# 2010    280
# 2002    274
# 2000    254
# 2013    248
# 1996    244
# 2004    244
# 2001    238
# 2014    236
# dtype: int64

# %%
top_matches_held_that_years = list(years_int_s.value_counts().head(15))
plt.title('Matches played in each year\n')
plt.xlabel("\nYears\n")
plt.ylabel("\nMatches\n")
sea.barplot(top15_years_by_matches_held, top_matches_held_that_years);
# Out:
# C:\Users\muham\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# for a graph of Maximum matches played in top 15 ground
matches_played_in_each_ground
# Out:
# Sharjah         452
# Colombo         358
# Dhaka           308
# Melbourne       300
# Sydney          294
#                ...
# Devonport         2
# Sargodha          2
# New Plymouth      2
# Whangarei         2
# Launceston        2
# Name: Ground, Length: 161, dtype: int64

# %%
grounds_top_15 = pd.DataFrame(matches_played_in_each_ground.head(15))
grounds_top_15
# Out:
#                Ground
# Sharjah           452
# Colombo           358
# Dhaka             308
# Melbourne         300
# Sydney            294
# Harare            268
# Adelaide          160
# Perth             158
# Nairobi           154
# Brisbane          144
# Auckland          142
# Bulawayo          134
# The Oval          128
# Port of Spain     124
# Lahore            116

# %%
type(grounds_top_15)
# Out:
# pandas.core.frame.DataFrame

# %%
sea.set_style('darkgrid')
grounds_top_15.plot(kind='line', 
                    xlabel='\nGrounds\n', 
                    ylabel = '\nMatches Played\n', 
                    title='\nMaximum matches played in top 15 ground\n', 
                    yticks=[x for x in range(25,470,25)],
                    figsize=(13,8));

# %%
sea.set_style('darkgrid')
grounds_top_15.plot(kind='bar', 
                    xlabel='\nGrounds\n', 
                    ylabel = '\nMatches Played\n', 
                    title='\nMaximum matches played in top 15 ground\n', 
                    yticks=[x for x in range(25,470,25)],
                    figsize=(13,8));

# %%
sea.set_style('darkgrid')
grounds_top_15.plot(kind='box', 
                    xlabel='\nGrounds\n', 
                    ylabel = '\nMatches Played\n', 
                    title='\nMaximum matches played in top 15 ground\n', 
                    yticks=[x for x in range(25,470,25)],
                    figsize=(13,8));

# %%
matches_played_in_pakistani_grounds
# Out:
# Gujranwala      22
# Sahiwal          2
# Lahore         116
# Peshawar        30
# Rawalpindi      46
# Karachi         88
# Quetta           6
# Sargodha         2
# Sheikhupura      4
# Sialkot         16
# Multan          26
# Faisalabad      32
# Hyderabad       48
# Name: Ground, dtype: int64

# %%
top_5_pakistani_ground = pd.DataFrame(matches_played_in_pakistani_grounds)
top_5_pakistani_ground = top_5_pakistani_ground.nlargest(5, ['Ground']) 
top_5_pakistani_ground
# Out:
#             Ground
# Lahore         116
# Karachi         88
# Hyderabad       48
# Rawalpindi      46
# Faisalabad      32

# %%
top_5_pakistani_ground.reset_index(inplace = True)
top_5_pakistani_ground
#top_5_pakistani_ground = top_5_pakistani_ground.rename(columns={'index':'Ground', 'Ground':'Matches'}) 
#top_5_pakistani_ground
# Out:
#         index  Ground
# 0      Lahore     116
# 1     Karachi      88
# 2   Hyderabad      48
# 3  Rawalpindi      46
# 4  Faisalabad      32

# %%
top_5_pakistani_ground = top_5_pakistani_ground.rename(columns={'index':'Ground', 'Ground':'Matches'}) 
top_5_pakistani_ground
# Out:
#        Ground  Matches
# 0      Lahore      116
# 1     Karachi       88
# 2   Hyderabad       48
# 3  Rawalpindi       46
# 4  Faisalabad       32

# %%
sea.set_style('darkgrid')

plt.title("Maximum matches_played_in_Top_5_Pakistani_grounds")
plt.xticks(range(0,500,25))
sea.barplot(top_5_pakistani_ground.Ground, top_5_pakistani_ground.Matches, linewidth=50);
plt.xlabel('\nMatches\n');
plt.ylabel('Grounds→');
# Out:
# C:\Users\muham\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
top_won_country =  odi_df['Winner'].value_counts().head(10)
top_won_country_df = pd.DataFrame(top_won_country)
top_won_country_df
# Out:
#               Winner
# Australia       1104
# India            950
# Pakistan         932
# West Indies      760
# Sri Lanka        742
# South Africa     722
# England          686
# New Zealand      648
# Zimbabwe         258
# Bangladesh       210

# %%
top_won_country_df.reset_index(inplace=True)
top_won_country_df = top_won_country_df.rename(columns={"index":"Countries", 'Winner':'Matches-Won'})
top_won_country_df
# Out:
#       Countries  Matches-Won
# 0     Australia         1104
# 1         India          950
# 2      Pakistan          932
# 3   West Indies          760
# 4     Sri Lanka          742
# 5  South Africa          722
# 6       England          686
# 7   New Zealand          648
# 8      Zimbabwe          258
# 9    Bangladesh          210

# %%
plt.title("Maximum matches won by top 10 country")
plt.yticks(ticks = [x for x in range(0,1200,90)])
plt.xlabel('Counttries')
plt.ylabel('Matches')
plt.bar(top_won_country_df.Countries, top_won_country_df["Matches-Won"], color="black");

# %%
plt.title("Maximum matches won by top 10 country")
plt.yticks(ticks = [x for x in range(0,1200,60)])
plt.xlabel('\nCounttries\n')
plt.ylabel('Matches')
plt.plot(top_won_country_df.Countries, top_won_country_df["Matches-Won"], marker='o', color='black')

# %%
max_hosted_country_df = pd.DataFrame(odi_df['Host_Country'].value_counts().head(10))
max_hosted_country_df.reset_index(inplace=True)
max_hosted_country_df
# Out:
#           index  Host_Country
# 0     Australia          1170
# 1         India           792
# 2       England           774
# 3  South Africa           628
# 4   New Zealand           602
# 5        U.A.E.           590
# 6   West Indies           570
# 7     Sri Lanka           522
# 8      Zimbabwe           404
# 9    Bangladesh           398

# %%
max_hosted_country_df = max_hosted_country_df.rename(columns={'index':'Countries', 'Host_Country':'Total_Matches_Hosted'})
max_hosted_country_df
# Out:
#       Countries  Total_Matches_Hosted
# 0     Australia                  1170
# 1         India                   792
# 2       England                   774
# 3  South Africa                   628
# 4   New Zealand                   602
# 5        U.A.E.                   590
# 6   West Indies                   570
# 7     Sri Lanka                   522
# 8      Zimbabwe                   404
# 9    Bangladesh                   398

# %%
odi_df[odi_df['Host_Country'] == odi_df['Winner']]
# Out:
#        Scorecard       Team 1        Team 2           Margin        Ground  \
# 0        ODI # 1    Australia       England  Winner2ndInning     Melbourne
# 1        ODI # 2      England     Australia  Winner2ndInning    Manchester
# 3        ODI # 4      England     Australia  Winner2ndInning    Birmingham
# 4        ODI # 5  New Zealand      Pakistan  Winner1stInning  Christchurch
# 5        ODI # 6      England   New Zealand  Winner2ndInning       Swansea
# ...          ...          ...           ...              ...           ...
# 7481  ODI # 3923   Bangladesh  South Africa  Winner2ndInning     Kimberley
# 7483  ODI # 3925   Bangladesh  South Africa  Winner1stInning         Paarl
# 7487  ODI # 3929   Bangladesh  South Africa  Winner1stInning   East London
# 7489  ODI # 3931  New Zealand         India  Winner2ndInning          Pune
# 7490  ODI # 3932  New Zealand         India  Winner1stInning        Kanpur
#
#         Match Date        Winner  Host_Country Venue_Team1
# ...

# %%
top_won_country =  odi_df['Winner'].value_counts().head(10)
top_won_country
# Out:
# Australia       1104
# India            950
# Pakistan         932
# West Indies      760
# Sri Lanka        742
# South Africa     722
# England          686
# New Zealand      648
# Zimbabwe         258
# Bangladesh       210
# Name: Winner, dtype: int64

# %%
bottom_won_country = odi_df['Winner'].value_counts().tail(10)
bottom_won_country
# Out:
# Scotland       62
# Netherlands    56
# Canada         34
# U.A.E.         18
# Bermuda        14
# Hong Kong      12
# P.N.G.         10
# East Africa     2
# U.S.A.          2
# Namibia         2
# Name: Winner, dtype: int64

# %%
fig, axis = plt.subplots(1, 2, figsize=(17, 12)) 

axis[0].set_title('top ten won countries')       
sea.barplot(top_won_country,
            top_won_country.index,
            ax = axis[0]);                       


axis[1].set_title('Bottom ten won countries')    
sea.barplot(bottom_won_country,
            bottom_won_country.index,
            ax = axis[1]);                        
plt.xlabel('Matches Won');
# Out:
# C:\Users\muham\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\muham\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
first_odi = odi_df.iloc[0]
first_odi
# Out:
# Scorecard               ODI # 1
# Team 1                Australia
# Team 2                  England
# Margin          Winner2ndInning
# Ground                Melbourne
# Match Date          Jan 5, 1971
# Winner                Australia
# Host_Country          Australia
# Venue_Team1                Home
# Name: 0, dtype: object

# %%
ground=grounds_top_15
ground
# Out:
#                Ground
# Sharjah           452
# Colombo           358
# Dhaka             308
# Melbourne         300
# Sydney            294
# Harare            268
# Adelaide          160
# Perth             158
# Nairobi           154
# Brisbane          144
# Auckland          142
# Bulawayo          134
# The Oval          128
# Port of Spain     124
# Lahore            116

# %%
plt.title("where maximum matches have played?")
plt.yticks(ticks = [x for x in range(0,500,25)])
plt.xlabel('\nGrounds\n')
plt.ylabel('Matches')
plt.plot(ground.index,ground, marker='o', color='black')

# %%
odi_df[odi_df['Winner'] != odi_df['Host_Country']]
# Out:
#        Scorecard       Team 1       Team 2           Margin        Ground  \
# 2        ODI # 3      England    Australia  Winner2ndInning        Lord's
# 7        ODI # 9      England  West Indies  Winner2ndInning      The Oval
# 8       ODI # 10  New Zealand    Australia  Winner2ndInning       Dunedin
# 9       ODI # 11  New Zealand    Australia  Winner1stInning  Christchurch
# 12      ODI # 14      England     Pakistan  Winner2ndInning    Nottingham
# ...          ...          ...          ...              ...           ...
# 7486  ODI # 3928  New Zealand        India  Winner2ndInning        Mumbai
# 7488  ODI # 3930    Sri Lanka     Pakistan  Winner2ndInning       Sharjah
# 7491  ODI # 3933      Namibia    Hong Kong  Winner2ndInning        Mumbai
# 7492  ODI # 3934       U.S.A.      Bermuda  Winner2ndInning        Mumbai
# 7493  ODI # 3935      Namibia  East Africa  Winner1stInning        Mumbai
#
#         Match Date       Winner Host_Country Venue_Team1
# ...

# %%
team_won_away_from_homegrounds_df =  odi_df[odi_df['Winner'] != odi_df['Host_Country']]
top15_team_won_away_from_homegrounds_df = pd.DataFrame(team_won_away_from_homegrounds_df['Winner'].value_counts().head(15))
top15_team_won_away_from_homegrounds_df = top15_team_won_away_from_homegrounds_df.rename(columns={'Winner':'Matches_Won_when_played_in_other_countries_ground'})
top15_team_won_away_from_homegrounds_df
# Out:
#               Matches_Won_when_played_in_other_countries_ground
# Pakistan                                                    730
# India                                                       592
# Australia                                                   556
# West Indies                                                 502
# Sri Lanka                                                   468
# South Africa                                                386
# England                                                     366
# New Zealand                                                 324
# Zimbabwe                                                    142
# Afghanistan                                                  84
# Bangladesh                                                   82
# Ireland                                                      62
# Kenya                                                        38
# Netherlands                                                  34
# ...

# %%
plt.title('\n\n\nTop 15 countries which won maximum matches when they played in the away from to the hometown grounds\n\n\n')
plt.xticks(range(0,750,60))

sea.barplot(top15_team_won_away_from_homegrounds_df['Matches_Won_when_played_in_other_countries_ground'],  top15_team_won_away_from_homegrounds_df.index);
plt.xlabel('\n\nMatches won in the other countries ground\n\n')
plt.ylabel('\n\nCountries\n\n');
# Out:
# C:\Users\muham\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
Hosts_counts=odi_df.Host_Country.value_counts().head(10)
Hosts_counts
# Out:
# Australia       1170
# India            792
# England          774
# South Africa     628
# New Zealand      602
# U.A.E.           590
# West Indies      570
# Sri Lanka        522
# Zimbabwe         404
# Bangladesh       398
# Name: Host_Country, dtype: int64

# %%
plt.title('Matches hosted by Countries')
plt.pie(Hosts_counts,labels=Hosts_counts.index);

# %%
plt.title('Matches hosted by Countries')
plt.pie(Hosts_counts,labels=Hosts_counts.index,autopct='%1.1f%%',startangle=90);

# %%
comparison_column = np.where(odi_df["Winner"] == odi_df["Host_Country"], True, False)
home_wins=comparison_column.sum()
Venues=odi_df.Venue_Team1.value_counts()
neutral_venues=Venues[2]
home_loses=7024-home_wins-neutral_venues

# %%
plt.title('Home Match Results')
plt.pie((home_wins,home_loses),labels=('home wins','home loses'),autopct='%1.1f%%');
